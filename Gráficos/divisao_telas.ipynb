# %% [markdown]
# <a href="https://colab.research.google.com/github/oliveiraprg/formacao-cientista-de-dados/blob/main/Gr%C3%A1ficos/divisao_telas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Divisão de Telas(Subgráficos)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
base = pd.read_csv('/content/trees.csv')
base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
#Girth com Volume
plt.scatter(base.Girth, base.Volume)

# %%
#Girth com heigth
plt.scatter(base.Girth, base.Height)

# %%
#Height com Volume
plt.scatter(base.Height, base.Volume, marker='*')

# %%
plt.hist(base.Volume)
# Out:
# (array([ 5., 10.,  4.,  4.,  2.,  0.,  4.,  1.,  0.,  1.]),
#  array([10.2 , 16.88, 23.56, 30.24, 36.92, 43.6 , 50.28, 56.96, 63.64,
#         70.32, 77.  ]),
#  <BarContainer object of 10 artists>)

# %%
#Imprimindo os gráficos juntos
plt.figure(2)

plt.suptitle('Árvores', fontsize=16)

plt.subplot(2,2,1)
plt.scatter(base.Girth, base.Volume)
plt.ylabel('Volume')
plt.xlabel('Circunferência')
plt.title('Dispersão da Circunferência vs Volume', fontsize=10)

plt.subplot(2,2,2)
plt.scatter(base.Girth, base.Height)
plt.ylabel('Altura')
plt.xlabel('Circunferência')
plt.title('Dispersão da Circunferência vs Altura', fontsize=10)

plt.subplot(2,2,3)
plt.scatter(base.Height, base.Volume, marker='*')
plt.xlabel('Altura')
plt.ylabel('Volume')
plt.title('Dispersão da Altura vs Volume', fontsize=10)

plt.subplot(2,2,4)
plt.hist(base.Volume)
plt.xlabel('Volume')
plt.ylabel('Frequência')
plt.title('Histograma do Volume', fontsize=10)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
